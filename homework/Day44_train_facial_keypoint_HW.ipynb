# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\a2688\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\a2688\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\a2688\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 21s 12ms/step - loss: 0.0063 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00229, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00229 to 0.00194, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00194
# Epoch 4/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00194 to 0.00189, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00183, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00183 to 0.00173, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 8.6641e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00173 to 0.00161, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 7.5791e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00161 to 0.00158, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 6.5827e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00158 to 0.00132, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 5.8328e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00132 to 0.00115, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 5.2983e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00115 to 0.00111, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 4.8208e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00111 to 0.00106, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.5695e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00106 to 0.00103, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.2859e-04 - val_loss: 9.5613e-04
#
# Epoch 00014: val_loss improved from 0.00103 to 0.00096, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 3.9114e-04 - val_loss: 9.5697e-04
#
# Epoch 00015: val_loss did not improve from 0.00096
# Epoch 16/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 3.7469e-04 - val_loss: 8.9889e-04
#
# Epoch 00016: val_loss improved from 0.00096 to 0.00090, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 3.6537e-04 - val_loss: 9.7085e-04
#
# Epoch 00017: val_loss did not improve from 0.00090
# Epoch 18/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 3.4556e-04 - val_loss: 8.6862e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 3.3000e-04 - val_loss: 8.8088e-04
#
# Epoch 00019: val_loss did not improve from 0.00087
# Epoch 20/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 3.2769e-04 - val_loss: 8.5392e-04
#
# Epoch 00020: val_loss improved from 0.00087 to 0.00085, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 3.0378e-04 - val_loss: 8.3163e-04
#
# Epoch 00021: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9595e-04 - val_loss: 8.6298e-04
#
# Epoch 00022: val_loss did not improve from 0.00083
# Epoch 23/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 2.8133e-04 - val_loss: 8.3693e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 15s 9ms/step - loss: 2.9219e-04 - val_loss: 8.3010e-04
#
# Epoch 00024: val_loss improved from 0.00083 to 0.00083, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 17s 10ms/step - loss: 2.7590e-04 - val_loss: 8.3795e-04
#
# Epoch 00025: val_loss did not improve from 0.00083
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6826e-04 - val_loss: 7.9359e-04
#
# Epoch 00026: val_loss improved from 0.00083 to 0.00079, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6738e-04 - val_loss: 7.9241e-04
#
# Epoch 00027: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4644e-04 - val_loss: 8.1285e-04
#
# Epoch 00028: val_loss did not improve from 0.00079
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5158e-04 - val_loss: 8.0139e-04
#
# Epoch 00029: val_loss did not improve from 0.00079
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4258e-04 - val_loss: 7.9195e-04
#
# Epoch 00030: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 2.3920e-04 - val_loss: 7.8111e-04
#
# Epoch 00031: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 2.4091e-04 - val_loss: 7.7904e-04
#
# Epoch 00032: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 2.2914e-04 - val_loss: 7.8237e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 2.2695e-04 - val_loss: 8.0639e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 2.2160e-04 - val_loss: 7.8160e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 2.1952e-04 - val_loss: 7.7633e-04
#
# Epoch 00036: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 2.1768e-04 - val_loss: 7.8868e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 2.1183e-04 - val_loss: 7.8404e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0439e-04 - val_loss: 7.6627e-04
#
# Epoch 00039: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 2.0311e-04 - val_loss: 8.0781e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0288e-04 - val_loss: 7.7828e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.9526e-04 - val_loss: 7.9720e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.9753e-04 - val_loss: 7.6493e-04
#
# Epoch 00043: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.9983e-04 - val_loss: 7.6007e-04
#
# Epoch 00044: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.8816e-04 - val_loss: 7.5966e-04
#
# Epoch 00045: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.8924e-04 - val_loss: 7.6924e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.8100e-04 - val_loss: 7.6052e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.8286e-04 - val_loss: 7.7021e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.8271e-04 - val_loss: 7.4906e-04
#
# Epoch 00049: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.7654e-04 - val_loss: 7.8437e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.7433e-04 - val_loss: 7.4679e-04
#
# Epoch 00051: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.7326e-04 - val_loss: 7.4897e-04
#
# Epoch 00052: val_loss did not improve from 0.00075
# Epoch 53/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.7736e-04 - val_loss: 7.4172e-04
#
# Epoch 00053: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6826e-04 - val_loss: 7.7307e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 16s 9ms/step - loss: 1.6868e-04 - val_loss: 7.4995e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.6623e-04 - val_loss: 7.2902e-04
#
# Epoch 00056: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 57/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.5956e-04 - val_loss: 7.5170e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.6386e-04 - val_loss: 7.6708e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.5506e-04 - val_loss: 7.5297e-04
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.5639e-04 - val_loss: 7.7068e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.5485e-04 - val_loss: 7.4554e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.5724e-04 - val_loss: 7.2978e-04
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.5709e-04 - val_loss: 7.6864e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.5155e-04 - val_loss: 7.5680e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4956e-04 - val_loss: 7.6026e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4928e-04 - val_loss: 7.3631e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4778e-04 - val_loss: 7.5276e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.5173e-04 - val_loss: 7.3999e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4565e-04 - val_loss: 7.5144e-04
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 1712/1712 [==============================] - 13s 8ms/step - loss: 1.4447e-04 - val_loss: 7.4431e-04
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.4118e-04 - val_loss: 7.5001e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 1.4233e-04 - val_loss: 7.1228e-04
#
# Epoch 00072: val_loss improved from 0.00073 to 0.00071, saving model to best_weights.h5
# Epoch 73/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.4441e-04 - val_loss: 7.2006e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3849e-04 - val_loss: 7.3121e-04
#
# Epoch 00074: val_loss did not improve from 0.00071
# Epoch 75/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3886e-04 - val_loss: 7.3803e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2964e-04 - val_loss: 7.3677e-04
#
# Epoch 00076: val_loss did not improve from 0.00071
# Epoch 77/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3570e-04 - val_loss: 7.6196e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3196e-04 - val_loss: 7.3041e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3388e-04 - val_loss: 7.5111e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.3187e-04 - val_loss: 7.3488e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2762e-04 - val_loss: 7.3597e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2686e-04 - val_loss: 7.2919e-04
#
# Epoch 00082: val_loss did not improve from 0.00071
# Epoch 83/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2651e-04 - val_loss: 7.5107e-04
#
# Epoch 00083: val_loss did not improve from 0.00071
# Epoch 84/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2754e-04 - val_loss: 7.4135e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2703e-04 - val_loss: 7.2113e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2359e-04 - val_loss: 7.0754e-04
#
# Epoch 00086: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 87/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2105e-04 - val_loss: 7.5705e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2031e-04 - val_loss: 7.3471e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2236e-04 - val_loss: 7.4479e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2083e-04 - val_loss: 7.4814e-04
#
# Epoch 00090: val_loss did not improve from 0.00071
# Epoch 91/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.2159e-04 - val_loss: 7.4829e-04
#
# Epoch 00091: val_loss did not improve from 0.00071
# Epoch 92/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1759e-04 - val_loss: 7.3866e-04
#
# Epoch 00092: val_loss did not improve from 0.00071
# Epoch 93/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1605e-04 - val_loss: 7.7844e-04
#
# Epoch 00093: val_loss did not improve from 0.00071
# Epoch 94/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1865e-04 - val_loss: 7.3965e-04
#
# Epoch 00094: val_loss did not improve from 0.00071
# Epoch 95/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1851e-04 - val_loss: 7.5210e-04
#
# Epoch 00095: val_loss did not improve from 0.00071
# Epoch 96/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1656e-04 - val_loss: 7.6557e-04
#
# Epoch 00096: val_loss did not improve from 0.00071
# Epoch 97/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1415e-04 - val_loss: 7.3007e-04
#
# Epoch 00097: val_loss did not improve from 0.00071
# Epoch 98/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1127e-04 - val_loss: 7.6982e-04
#
# Epoch 00098: val_loss did not improve from 0.00071
# Epoch 99/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0987e-04 - val_loss: 7.2710e-04
#
# Epoch 00099: val_loss did not improve from 0.00071
# Epoch 100/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1023e-04 - val_loss: 7.5693e-04
#
# Epoch 00100: val_loss did not improve from 0.00071
# Epoch 101/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.1128e-04 - val_loss: 7.3707e-04
#
# Epoch 00101: val_loss did not improve from 0.00071
# Epoch 102/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0773e-04 - val_loss: 7.5094e-04
#
# Epoch 00102: val_loss did not improve from 0.00071
# Epoch 103/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0727e-04 - val_loss: 7.3969e-04
#
# Epoch 00103: val_loss did not improve from 0.00071
# Epoch 104/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0807e-04 - val_loss: 7.1139e-04
#
# Epoch 00104: val_loss did not improve from 0.00071
# Epoch 105/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0636e-04 - val_loss: 7.2887e-04
#
# Epoch 00105: val_loss did not improve from 0.00071
# Epoch 106/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0674e-04 - val_loss: 7.4713e-04
#
# Epoch 00106: val_loss did not improve from 0.00071
# Epoch 107/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0699e-04 - val_loss: 7.4149e-04
#
# Epoch 00107: val_loss did not improve from 0.00071
# Epoch 108/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0773e-04 - val_loss: 7.6099e-04
#
# Epoch 00108: val_loss did not improve from 0.00071
# Epoch 109/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0416e-04 - val_loss: 7.6853e-04
#
# Epoch 00109: val_loss did not improve from 0.00071
# Epoch 110/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0519e-04 - val_loss: 7.3956e-04
#
# Epoch 00110: val_loss did not improve from 0.00071
# Epoch 111/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0451e-04 - val_loss: 7.7360e-04
#
# Epoch 00111: val_loss did not improve from 0.00071
# Epoch 112/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0450e-04 - val_loss: 7.4429e-04
#
# Epoch 00112: val_loss did not improve from 0.00071
# Epoch 113/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0373e-04 - val_loss: 7.4159e-04
#
# Epoch 00113: val_loss did not improve from 0.00071
# Epoch 114/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.9777e-05 - val_loss: 7.0479e-04
#
# Epoch 00114: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 115/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0255e-04 - val_loss: 7.6128e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.9727e-05 - val_loss: 7.4656e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.9183e-05 - val_loss: 7.1864e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.9764e-05 - val_loss: 7.1209e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.9349e-05 - val_loss: 7.3243e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0006e-04 - val_loss: 7.8499e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 1.0269e-04 - val_loss: 7.4058e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.7122e-05 - val_loss: 7.3290e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.5745e-05 - val_loss: 7.2501e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.7424e-05 - val_loss: 7.4217e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.5011e-05 - val_loss: 7.5232e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.1459e-05 - val_loss: 7.3224e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.3676e-05 - val_loss: 7.4371e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.4949e-05 - val_loss: 7.2855e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.5245e-05 - val_loss: 7.7121e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.0844e-05 - val_loss: 7.8630e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.2618e-05 - val_loss: 7.3408e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.3334e-05 - val_loss: 7.2897e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.2382e-05 - val_loss: 7.4438e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.1523e-05 - val_loss: 7.5762e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.7745e-05 - val_loss: 7.4802e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.8668e-05 - val_loss: 7.4999e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 9.0214e-05 - val_loss: 7.4213e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 8.6515e-05 - val_loss: 7.6439e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 13s 7ms/step - loss: 8.6544e-05 - val_loss: 7.4059e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.8190e-05 - val_loss: 7.4891e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.8533e-05 - val_loss: 7.5052e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.4136e-05 - val_loss: 7.3972e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.3943e-05 - val_loss: 7.4006e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.3541e-05 - val_loss: 7.3453e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.6210e-05 - val_loss: 7.4679e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.2877e-05 - val_loss: 7.5351e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.3386e-05 - val_loss: 7.3871e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.1987e-05 - val_loss: 7.4267e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.2465e-05 - val_loss: 7.4820e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 8.5284e-05 - val_loss: 7.6792e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _=load_data(dirname='test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 官方解答

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp=np.copy(new_points)
    new_points[0:2]=new_points_temp[2:4]
    new_points[2:4]=new_points_temp[0:2]
    new_points[4:6]=new_points_temp[8:10]
    new_points[6:8]=new_points_temp[10:12]
    new_points[8:10]=new_points_temp[4:6]
    new_points[10:12]=new_points_temp[6:8]
    new_points[12:14]=new_points_temp[16:18]
    new_points[14:16]=new_points_temp[18:20]
    new_points[16:18]=new_points_temp[12:14]
    new_points[18:20]=new_points_temp[14:16]
    new_points[22:24]=new_points_temp[24:26]
    new_points[24:26]=new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.0037 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00185, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00185
# Epoch 3/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00003: val_loss improved from 0.00185 to 0.00169, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.6590e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00169 to 0.00154, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 6.1575e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00154 to 0.00116, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 5.3246e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00116 to 0.00106, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 4.6502e-04 - val_loss: 9.4549e-04
#
# Epoch 00007: val_loss improved from 0.00106 to 0.00095, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 4.2143e-04 - val_loss: 9.1805e-04
#
# Epoch 00008: val_loss improved from 0.00095 to 0.00092, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 3.8955e-04 - val_loss: 9.0831e-04
#
# Epoch 00009: val_loss improved from 0.00092 to 0.00091, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 3.6316e-04 - val_loss: 8.3635e-04
#
# Epoch 00010: val_loss improved from 0.00091 to 0.00084, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 3.3480e-04 - val_loss: 7.9039e-04
#
# Epoch 00011: val_loss improved from 0.00084 to 0.00079, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 3.1662e-04 - val_loss: 8.0382e-04
#
# Epoch 00012: val_loss did not improve from 0.00079
# Epoch 13/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 3.0209e-04 - val_loss: 7.4193e-04
#
# Epoch 00013: val_loss improved from 0.00079 to 0.00074, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 2.9615e-04 - val_loss: 7.7515e-04
#
# Epoch 00014: val_loss did not improve from 0.00074
# Epoch 15/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 2.7644e-04 - val_loss: 7.2092e-04
#
# Epoch 00015: val_loss improved from 0.00074 to 0.00072, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.6423e-04 - val_loss: 7.4337e-04
#
# Epoch 00016: val_loss did not improve from 0.00072
# Epoch 17/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.5574e-04 - val_loss: 7.1000e-04
#
# Epoch 00017: val_loss improved from 0.00072 to 0.00071, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 2.4983e-04 - val_loss: 7.2594e-04
#
# Epoch 00018: val_loss did not improve from 0.00071
# Epoch 19/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.4121e-04 - val_loss: 7.2798e-04
#
# Epoch 00019: val_loss did not improve from 0.00071
# Epoch 20/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.2991e-04 - val_loss: 6.7253e-04
#
# Epoch 00020: val_loss improved from 0.00071 to 0.00067, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.3043e-04 - val_loss: 7.1108e-04
#
# Epoch 00021: val_loss did not improve from 0.00067
# Epoch 22/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.1999e-04 - val_loss: 6.9876e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.1546e-04 - val_loss: 6.5574e-04
#
# Epoch 00023: val_loss improved from 0.00067 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 27s 8ms/step - loss: 2.1745e-04 - val_loss: 6.9202e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.0922e-04 - val_loss: 7.1790e-04
#
# Epoch 00025: val_loss did not improve from 0.00066
# Epoch 26/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 2.0008e-04 - val_loss: 6.8116e-04
#
# Epoch 00026: val_loss did not improve from 0.00066
# Epoch 27/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.9929e-04 - val_loss: 6.9504e-04
#
# Epoch 00027: val_loss did not improve from 0.00066
# Epoch 28/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.8982e-04 - val_loss: 6.8632e-04
#
# Epoch 00028: val_loss did not improve from 0.00066
# Epoch 29/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.8857e-04 - val_loss: 6.5840e-04
#
# Epoch 00029: val_loss did not improve from 0.00066
# Epoch 30/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.8350e-04 - val_loss: 7.2876e-04
#
# Epoch 00030: val_loss did not improve from 0.00066
# Epoch 31/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.8230e-04 - val_loss: 6.6215e-04
#
# Epoch 00031: val_loss did not improve from 0.00066
# Epoch 32/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.7467e-04 - val_loss: 7.2110e-04
#
# Epoch 00032: val_loss did not improve from 0.00066
# Epoch 33/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.7388e-04 - val_loss: 6.8767e-04
#
# Epoch 00033: val_loss did not improve from 0.00066
# Epoch 34/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.7136e-04 - val_loss: 6.4479e-04
#
# Epoch 00034: val_loss improved from 0.00066 to 0.00064, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.6778e-04 - val_loss: 6.9063e-04
#
# Epoch 00035: val_loss did not improve from 0.00064
# Epoch 36/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.6581e-04 - val_loss: 6.5225e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.6247e-04 - val_loss: 6.4674e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.5659e-04 - val_loss: 6.5561e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.5590e-04 - val_loss: 6.9176e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.5470e-04 - val_loss: 6.7978e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.4776e-04 - val_loss: 6.5727e-04
#
# Epoch 00041: val_loss did not improve from 0.00064
# Epoch 42/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.4835e-04 - val_loss: 6.4210e-04
#
# Epoch 00042: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 43/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.4831e-04 - val_loss: 6.3809e-04
#
# Epoch 00043: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.4819e-04 - val_loss: 6.3434e-04
#
# Epoch 00044: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 45/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.4625e-04 - val_loss: 6.4205e-04
#
# Epoch 00045: val_loss did not improve from 0.00063
# Epoch 46/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.4290e-04 - val_loss: 6.8649e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.3762e-04 - val_loss: 6.4036e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.3920e-04 - val_loss: 6.4840e-04
#
# Epoch 00048: val_loss did not improve from 0.00063
# Epoch 49/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.3881e-04 - val_loss: 6.5104e-04
#
# Epoch 00049: val_loss did not improve from 0.00063
# Epoch 50/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.3358e-04 - val_loss: 6.9925e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.3400e-04 - val_loss: 6.8365e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.3168e-04 - val_loss: 6.5116e-04
#
# Epoch 00052: val_loss did not improve from 0.00063
# Epoch 53/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.3149e-04 - val_loss: 6.5355e-04
#
# Epoch 00053: val_loss did not improve from 0.00063
# Epoch 54/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.2613e-04 - val_loss: 6.2926e-04
#
# Epoch 00054: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 55/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.2579e-04 - val_loss: 6.8011e-04
#
# Epoch 00055: val_loss did not improve from 0.00063
# Epoch 56/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.2610e-04 - val_loss: 6.5530e-04
#
# Epoch 00056: val_loss did not improve from 0.00063
# Epoch 57/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.2286e-04 - val_loss: 6.5339e-04
#
# Epoch 00057: val_loss did not improve from 0.00063
# Epoch 58/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.1956e-04 - val_loss: 6.5252e-04
#
# Epoch 00058: val_loss did not improve from 0.00063
# Epoch 59/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.2080e-04 - val_loss: 6.6692e-04
#
# Epoch 00059: val_loss did not improve from 0.00063
# Epoch 60/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.1903e-04 - val_loss: 6.5710e-04
#
# Epoch 00060: val_loss did not improve from 0.00063
# Epoch 61/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.2382e-04 - val_loss: 6.6660e-04
#
# Epoch 00061: val_loss did not improve from 0.00063
# Epoch 62/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.2082e-04 - val_loss: 6.3960e-04
#
# Epoch 00062: val_loss did not improve from 0.00063
# Epoch 63/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.1569e-04 - val_loss: 6.6326e-04
#
# Epoch 00063: val_loss did not improve from 0.00063
# Epoch 64/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.1819e-04 - val_loss: 6.3983e-04
#
# Epoch 00064: val_loss did not improve from 0.00063
# Epoch 65/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.1183e-04 - val_loss: 6.6225e-04
#
# Epoch 00065: val_loss did not improve from 0.00063
# Epoch 66/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.1066e-04 - val_loss: 6.4049e-04
#
# Epoch 00066: val_loss did not improve from 0.00063
# Epoch 67/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.1101e-04 - val_loss: 6.5063e-04
#
# Epoch 00067: val_loss did not improve from 0.00063
# Epoch 68/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0773e-04 - val_loss: 6.5267e-04
#
# Epoch 00068: val_loss did not improve from 0.00063
# Epoch 69/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0788e-04 - val_loss: 6.8689e-04
#
# Epoch 00069: val_loss did not improve from 0.00063
# Epoch 70/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0777e-04 - val_loss: 6.4378e-04
#
# Epoch 00070: val_loss did not improve from 0.00063
# Epoch 71/150
# 3424/3424 [==============================] - 26s 8ms/step - loss: 1.0584e-04 - val_loss: 6.3726e-04
#
# Epoch 00071: val_loss did not improve from 0.00063
# Epoch 72/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0540e-04 - val_loss: 6.6054e-04
#
# Epoch 00072: val_loss did not improve from 0.00063
# Epoch 73/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0311e-04 - val_loss: 6.5922e-04
#
# Epoch 00073: val_loss did not improve from 0.00063
# Epoch 74/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.0289e-04 - val_loss: 6.5582e-04
#
# Epoch 00074: val_loss did not improve from 0.00063
# Epoch 75/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 1.0291e-04 - val_loss: 6.6126e-04
#
# Epoch 00075: val_loss did not improve from 0.00063
# Epoch 76/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0067e-04 - val_loss: 6.6276e-04
#
# Epoch 00076: val_loss did not improve from 0.00063
# Epoch 77/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.8752e-05 - val_loss: 6.2265e-04
#
# Epoch 00077: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 78/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.8643e-05 - val_loss: 6.3894e-04
#
# Epoch 00078: val_loss did not improve from 0.00062
# Epoch 79/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0065e-04 - val_loss: 6.7648e-04
#
# Epoch 00079: val_loss did not improve from 0.00062
# Epoch 80/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0119e-04 - val_loss: 6.3121e-04
#
# Epoch 00080: val_loss did not improve from 0.00062
# Epoch 81/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0134e-04 - val_loss: 6.3650e-04
#
# Epoch 00081: val_loss did not improve from 0.00062
# Epoch 82/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0547e-04 - val_loss: 6.6113e-04
#
# Epoch 00082: val_loss did not improve from 0.00062
# Epoch 83/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0920e-04 - val_loss: 6.5355e-04
#
# Epoch 00083: val_loss did not improve from 0.00062
# Epoch 84/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 1.0008e-04 - val_loss: 6.4276e-04
#
# Epoch 00084: val_loss did not improve from 0.00062
# Epoch 85/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.6198e-05 - val_loss: 6.6719e-04
#
# Epoch 00085: val_loss did not improve from 0.00062
# Epoch 86/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.5866e-05 - val_loss: 6.5855e-04
#
# Epoch 00086: val_loss did not improve from 0.00062
# Epoch 87/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.4095e-05 - val_loss: 6.4158e-04
#
# Epoch 00087: val_loss did not improve from 0.00062
# Epoch 88/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.4263e-05 - val_loss: 6.4132e-04
#
# Epoch 00088: val_loss did not improve from 0.00062
# Epoch 89/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.5257e-05 - val_loss: 6.2829e-04
#
# Epoch 00089: val_loss did not improve from 0.00062
# Epoch 90/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.2541e-05 - val_loss: 6.5775e-04
#
# Epoch 00090: val_loss did not improve from 0.00062
# Epoch 91/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.1552e-05 - val_loss: 6.3947e-04
#
# Epoch 00091: val_loss did not improve from 0.00062
# Epoch 92/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.4621e-05 - val_loss: 6.7472e-04
#
# Epoch 00092: val_loss did not improve from 0.00062
# Epoch 93/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 9.1744e-05 - val_loss: 6.3891e-04
#
# Epoch 00093: val_loss did not improve from 0.00062
# Epoch 94/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.9931e-05 - val_loss: 6.5843e-04
#
# Epoch 00094: val_loss did not improve from 0.00062
# Epoch 95/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.8508e-05 - val_loss: 6.4619e-04
#
# Epoch 00095: val_loss did not improve from 0.00062
# Epoch 96/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.9870e-05 - val_loss: 6.7335e-04
#
# Epoch 00096: val_loss did not improve from 0.00062
# Epoch 97/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 9.0539e-05 - val_loss: 6.4831e-04
#
# Epoch 00097: val_loss did not improve from 0.00062
# Epoch 98/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.9659e-05 - val_loss: 6.3560e-04
#
# Epoch 00098: val_loss did not improve from 0.00062
# Epoch 99/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.7624e-05 - val_loss: 6.2494e-04
#
# Epoch 00099: val_loss did not improve from 0.00062
# Epoch 100/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.5431e-05 - val_loss: 6.5069e-04
#
# Epoch 00100: val_loss did not improve from 0.00062
# Epoch 101/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.8612e-05 - val_loss: 6.2683e-04
#
# Epoch 00101: val_loss did not improve from 0.00062
# Epoch 102/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.7228e-05 - val_loss: 6.5045e-04
#
# Epoch 00102: val_loss did not improve from 0.00062
# Epoch 103/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.7111e-05 - val_loss: 6.4422e-04
#
# Epoch 00103: val_loss did not improve from 0.00062
# Epoch 104/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.8478e-05 - val_loss: 6.3551e-04
#
# Epoch 00104: val_loss did not improve from 0.00062
# Epoch 105/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.4768e-05 - val_loss: 6.6061e-04
#
# Epoch 00105: val_loss did not improve from 0.00062
# Epoch 106/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.6798e-05 - val_loss: 6.6340e-04
#
# Epoch 00106: val_loss did not improve from 0.00062
# Epoch 107/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.6162e-05 - val_loss: 6.4355e-04
#
# Epoch 00107: val_loss did not improve from 0.00062
# Epoch 108/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.6608e-05 - val_loss: 6.4742e-04
#
# Epoch 00108: val_loss did not improve from 0.00062
# Epoch 109/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.4229e-05 - val_loss: 6.4719e-04
#
# Epoch 00109: val_loss did not improve from 0.00062
# Epoch 110/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.6504e-05 - val_loss: 6.3220e-04
#
# Epoch 00110: val_loss did not improve from 0.00062
# Epoch 111/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.7298e-05 - val_loss: 6.6384e-04
#
# Epoch 00111: val_loss did not improve from 0.00062
# Epoch 112/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.6071e-05 - val_loss: 6.4846e-04
#
# Epoch 00112: val_loss did not improve from 0.00062
# Epoch 113/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.1974e-05 - val_loss: 6.6912e-04
#
# Epoch 00113: val_loss did not improve from 0.00062
# Epoch 114/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.1297e-05 - val_loss: 6.5288e-04
#
# Epoch 00114: val_loss did not improve from 0.00062
# Epoch 115/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.0902e-05 - val_loss: 6.4445e-04
#
# Epoch 00115: val_loss did not improve from 0.00062
# Epoch 116/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.2030e-05 - val_loss: 6.6098e-04
#
# Epoch 00116: val_loss did not improve from 0.00062
# Epoch 117/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.2005e-05 - val_loss: 6.4159e-04
#
# Epoch 00117: val_loss did not improve from 0.00062
# Epoch 118/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.1382e-05 - val_loss: 6.5201e-04
#
# Epoch 00118: val_loss did not improve from 0.00062
# Epoch 119/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.0942e-05 - val_loss: 6.3478e-04
#
# Epoch 00119: val_loss did not improve from 0.00062
# Epoch 120/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.2623e-05 - val_loss: 6.5802e-04
#
# Epoch 00120: val_loss did not improve from 0.00062
# Epoch 121/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.9912e-05 - val_loss: 6.6496e-04
#
# Epoch 00121: val_loss did not improve from 0.00062
# Epoch 122/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 8.1025e-05 - val_loss: 6.6307e-04
#
# Epoch 00122: val_loss did not improve from 0.00062
# Epoch 123/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.1356e-05 - val_loss: 6.6155e-04
#
# Epoch 00123: val_loss did not improve from 0.00062
# Epoch 124/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.8568e-05 - val_loss: 6.6512e-04
#
# Epoch 00124: val_loss did not improve from 0.00062
# Epoch 125/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.9407e-05 - val_loss: 6.6899e-04
#
# Epoch 00125: val_loss did not improve from 0.00062
# Epoch 126/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.1251e-05 - val_loss: 6.6677e-04
#
# Epoch 00126: val_loss did not improve from 0.00062
# Epoch 127/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.8483e-05 - val_loss: 6.3912e-04
#
# Epoch 00127: val_loss did not improve from 0.00062
# Epoch 128/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 8.0186e-05 - val_loss: 6.4430e-04
#
# Epoch 00128: val_loss did not improve from 0.00062
# Epoch 129/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.7471e-05 - val_loss: 6.2980e-04
#
# Epoch 00129: val_loss did not improve from 0.00062
# Epoch 130/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.6785e-05 - val_loss: 6.5182e-04
#
# Epoch 00130: val_loss did not improve from 0.00062
# Epoch 131/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.8130e-05 - val_loss: 6.3970e-04
#
# Epoch 00131: val_loss did not improve from 0.00062
# Epoch 132/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.9280e-05 - val_loss: 6.4401e-04
#
# Epoch 00132: val_loss did not improve from 0.00062
# Epoch 133/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.7923e-05 - val_loss: 6.5969e-04
#
# Epoch 00133: val_loss did not improve from 0.00062
# Epoch 134/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7370e-05 - val_loss: 6.6254e-04
#
# Epoch 00134: val_loss did not improve from 0.00062
# Epoch 135/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7483e-05 - val_loss: 6.3185e-04
#
# Epoch 00135: val_loss did not improve from 0.00062
# Epoch 136/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.8310e-05 - val_loss: 6.5005e-04
#
# Epoch 00136: val_loss did not improve from 0.00062
# Epoch 137/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7010e-05 - val_loss: 6.4582e-04
#
# Epoch 00137: val_loss did not improve from 0.00062
# Epoch 138/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7043e-05 - val_loss: 6.4456e-04
#
# Epoch 00138: val_loss did not improve from 0.00062
# Epoch 139/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7169e-05 - val_loss: 6.4657e-04
#
# Epoch 00139: val_loss did not improve from 0.00062
# Epoch 140/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.7866e-05 - val_loss: 6.5162e-04
#
# Epoch 00140: val_loss did not improve from 0.00062
# Epoch 141/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.7289e-05 - val_loss: 6.4265e-04
#
# Epoch 00141: val_loss did not improve from 0.00062
# Epoch 142/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.4729e-05 - val_loss: 6.4856e-04
#
# Epoch 00142: val_loss did not improve from 0.00062
# Epoch 143/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.6667e-05 - val_loss: 6.4395e-04
#
# Epoch 00143: val_loss did not improve from 0.00062
# Epoch 144/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7155e-05 - val_loss: 6.4410e-04
#
# Epoch 00144: val_loss did not improve from 0.00062
# Epoch 145/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.5117e-05 - val_loss: 6.5132e-04
#
# Epoch 00145: val_loss did not improve from 0.00062
# Epoch 146/150
# 3424/3424 [==============================] - 25s 7ms/step - loss: 7.7255e-05 - val_loss: 6.3880e-04
#
# Epoch 00146: val_loss did not improve from 0.00062
# Epoch 147/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.7761e-05 - val_loss: 6.5459e-04
#
# Epoch 00147: val_loss did not improve from 0.00062
# Epoch 148/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.8971e-05 - val_loss: 6.9284e-04
#
# Epoch 00148: val_loss did not improve from 0.00062
# Epoch 149/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.5632e-05 - val_loss: 6.5114e-04
#
# Epoch 00149: val_loss did not improve from 0.00062
# Epoch 150/150
# 3424/3424 [==============================] - 24s 7ms/step - loss: 7.4106e-05 - val_loss: 6.5848e-04
#
# Epoch 00150: val_loss did not improve from 0.00062

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
